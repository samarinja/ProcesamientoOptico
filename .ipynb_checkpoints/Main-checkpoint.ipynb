# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv2

def ploteo_complejo(mat,indicador,escalas):
    
    if(indicador=="I"):
        mat=np.abs(mat)**2
    elif(indicador=="A"):
        mat=np.abs(mat)
    elif(indicador=="p"):
        mat=np.angle(mat)
        
    if(escalas==1):
        plt.figure()
        plt.imshow(mat)
        plt.show()
    
    else:
        plt.figure()
        plt.imshow(np.log(mat+0.00001))
        plt.show()
    
    return 0

# %%
np.shape(cv2.imread('biblioteca.png',0))
# Out:
# (768, 768)

# %%
img=cv2.imread('biblioteca.png',0)
fft_img=np.fft.fftn(img)
fft_img=np.fft.fftshift(fft_img)


plt.figure()
plt.imshow(img)
plt.show()

ploteo_complejo(fft_img_prev,"I",0)
# Out:
# 0

# %%
mask = np.zeros((768,768),dtype="uint8")
cv2.rectangle(mask,(50,150),(500,500),10,-1)
plt.figure()
plt.imshow(mask)
plt.show()

# %%
mask2 = np.ones(np.shape(img),dtype="uint8")
coordx=int(np.shape(img)[0]/2)
coordy=int(np.shape(img)[0]/2)

print(coord)

cv2.circle(mask2,(coordx,coordy),40,0,-1)
plt.figure()
plt.imshow(mask2)
plt.colorbar()
plt.show()
# Out:
# 384

# %%
new_img=np.fft.fftn(mask2*fft_img);
ploteo_complejo(new_img,"I",1)
# Out:
# 0

# %%
plt.figure()
plt.imshow(np.abs(new_img)**2)
plt.show()
